# %% [markdown]
# # Health Prediction

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Import Linear Regression machine learning library
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
import xgboost as xgb
import lightgbm as lgb

from utils import DFImputer, DummyTransformer, DFLabelEncoder, DateFormatter, DateTransformer

from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, StratifiedKFold
from sklearn.metrics import (
    r2_score, mean_absolute_error, mean_squared_error
)
from IPython.display import Image
from subprocess import call

import os
import seaborn as sns
sns.set(rc={'figure.figsize':(13,6)})

# %% [markdown]
# ## Load data

# %%
journey9 = pd.read_hdf('journey9.hdf', 'journey9')
journey9.tail().T
# Out:
#                                                      11955160  \
# expiry_principal_subscription_id                    999342700
# subscription_expiry_month                          2020-01-31
# subscription_registration_month                    2017-01-31
# subscription_expirying_in_month                             3
# Journey                                                     9
# months_since_registration                                  36
# subscription_expiry_transition_type                     Renew
# subscription_expiry_length                          1 Year(s)
# subscription_expiry_affiliate_id                          885
# subscription_expiry_affiliate_name                       ASUS
# subscription_expiry_channel                           Partner
# subscription_expiry_transaction_source                Website
# subscription_expiry_package_id                            430
# subscription_expiry_package_name              McAfee LiveSafe
# pkg_license_cnt                              UNLIMITED DEVICE
# subscription_expiry_user_click_source_group    Not Applicable
# subscription_expiring_country                              RU
# subscription_expiring_geo                                EMEA
# Opt_in_out_status                                         NaN
# opt_out_date                                              NaN
# opt_in_date                                               NaN
# Lost_type                                      Not Applicable
# ar_on_rundate                                               1
# renewal_Package_group                                     MLS
# All_device_count                                            1
# PC_device_count                                             1
# Mobile_device_count                                       NaN
# cui_actions                                               NaN
# av_users                                                  NaN
# app_launch_users                                          NaN
# appboost_users                                            NaN
# vpn_users                                                 NaN
# shredder_users                                            NaN
# quickclean_users                                          NaN
# wbStatus                                                  NaN
# waStatus                                                  NaN
# non_av_users                                              NaN
# no_of_features                                            NaN
# 0_month_renewal                                             1
# 1_month_renewal                                             1
#
#                                                      11955161  \
# expiry_principal_subscription_id                    999533724
# subscription_expiry_month                          2020-10-31
# subscription_registration_month                    2016-10-31
# subscription_expirying_in_month                             3
# Journey                                                     9
# months_since_registration                                  48
# subscription_expiry_transition_type                     Trial
# subscription_expiry_length                          1 Year(s)
# subscription_expiry_affiliate_id                         1274
# subscription_expiry_affiliate_name           Retail - General
# subscription_expiry_channel                            Retail
# subscription_expiry_transaction_source                Channel
# subscription_expiry_package_id                            430
# subscription_expiry_package_name              McAfee LiveSafe
# pkg_license_cnt                              UNLIMITED DEVICE
# subscription_expiry_user_click_source_group    Not Applicable
# subscription_expiring_country                              GB
# subscription_expiring_geo                                EMEA
# Opt_in_out_status                                         NaN
# opt_out_date                                              NaN
# opt_in_date                                               NaN
# Lost_type                                      Not Applicable
# ar_on_rundate                                               0
# renewal_Package_group                                     MLS
# All_device_count                                            2
# PC_device_count                                             1
# Mobile_device_count                                         1
# cui_actions                                                 0
# av_users                                                    1
# app_launch_users                                            0
# appboost_users                                              1
# vpn_users                                                   0
# shredder_users                                              0
# quickclean_users                                            0
# wbStatus                                                    0
# waStatus                                                    1
# non_av_users                                                2
# no_of_features                                              3
# 0_month_renewal                                             0
# 1_month_renewal                                             0
#
#                                                              11955162  \
# expiry_principal_subscription_id                            999582292
# subscription_expiry_month                                  2020-10-31
# subscription_registration_month                            2016-10-31
# subscription_expirying_in_month                                     3
# Journey                                                             9
# months_since_registration                                          48
# subscription_expiry_transition_type                             Renew
# subscription_expiry_length                                  1 Year(s)
# subscription_expiry_affiliate_id                                 1067
# subscription_expiry_affiliate_name           Hewlett Packard Consumer
# subscription_expiry_channel                                   Partner
# subscription_expiry_transaction_source                        Website
# subscription_expiry_package_id                                    430
# subscription_expiry_package_name                      McAfee LiveSafe
# pkg_license_cnt                                      UNLIMITED DEVICE
# subscription_expiry_user_click_source_group         RENEWMSCPROVISION
# subscription_expiring_country                                      US
# subscription_expiring_geo                                         NaN
# Opt_in_out_status                                                 NaN
# opt_out_date                                                      NaN
# opt_in_date                                                       NaN
# Lost_type                                              Not Applicable
# ar_on_rundate                                                       0
# renewal_Package_group                                             MLS
# All_device_count                                                    1
# PC_device_count                                                     1
# Mobile_device_count                                               NaN
# cui_actions                                                         0
# av_users                                                            1
# app_launch_users                                                    0
# appboost_users                                                      0
# vpn_users                                                           0
# shredder_users                                                      0
# quickclean_users                                                    0
# wbStatus                                                          NaN
# waStatus                                                          NaN
# non_av_users                                                      NaN
# no_of_features                                                    NaN
# 0_month_renewal                                                     1
# 1_month_renewal                                                     1
#
#                                                                       11955163  \
# expiry_principal_subscription_id                                     999640265
# subscription_expiry_month                                           2020-01-31
# subscription_registration_month                                     2016-08-31
# subscription_expirying_in_month                                              3
# Journey                                                                      9
# months_since_registration                                                   41
# subscription_expiry_transition_type                                      Renew
# subscription_expiry_length                                           1 Year(s)
# subscription_expiry_affiliate_id                                          1264
# subscription_expiry_affiliate_name           Office Depot - TechDepot Services
# subscription_expiry_channel                                             Retail
# subscription_expiry_transaction_source                                 Website
# subscription_expiry_package_id                                             430
# subscription_expiry_package_name                               McAfee LiveSafe
# pkg_license_cnt                                               UNLIMITED DEVICE
# subscription_expiry_user_click_source_group                     Not Applicable
# subscription_expiring_country                                               US
# subscription_expiring_geo                                                  NaN
# Opt_in_out_status                                                          NaN
# opt_out_date                                                               NaN
# opt_in_date                                                                NaN
# Lost_type                                                       Not Applicable
# ar_on_rundate                                                                1
# renewal_Package_group                                                      MLS
# All_device_count                                                             1
# PC_device_count                                                              1
# Mobile_device_count                                                        NaN
# cui_actions                                                                NaN
# av_users                                                                   NaN
# app_launch_users                                                           NaN
# appboost_users                                                             NaN
# vpn_users                                                                  NaN
# shredder_users                                                             NaN
# quickclean_users                                                           NaN
# wbStatus                                                                   NaN
# waStatus                                                                   NaN
# non_av_users                                                               NaN
# no_of_features                                                             NaN
# 0_month_renewal                                                              1
# 1_month_renewal                                                              1
#
#                                                              11955164
# expiry_principal_subscription_id                            999746566
# subscription_expiry_month                                  2020-11-30
# subscription_registration_month                            2016-11-30
# subscription_expirying_in_month                                     3
# Journey                                                             9
# months_since_registration                                          48
# subscription_expiry_transition_type                             Renew
# subscription_expiry_length                                  1 Year(s)
# subscription_expiry_affiliate_id                                 1067
# subscription_expiry_affiliate_name           Hewlett Packard Consumer
# subscription_expiry_channel                                   Partner
# subscription_expiry_transaction_source                        Website
# subscription_expiry_package_id                                    430
# subscription_expiry_package_name                      McAfee LiveSafe
# pkg_license_cnt                                      UNLIMITED DEVICE
# subscription_expiry_user_click_source_group            Not Applicable
# subscription_expiring_country                                      US
# subscription_expiring_geo                                         NaN
# Opt_in_out_status                                                 NaN
# opt_out_date                                                      NaN
# opt_in_date                                                       NaN
# Lost_type                                              Not Applicable
# ar_on_rundate                                                       1
# renewal_Package_group                                             MLS
# All_device_count                                                  NaN
# PC_device_count                                                   NaN
# Mobile_device_count                                               NaN
# cui_actions                                                       NaN
# av_users                                                          NaN
# app_launch_users                                                  NaN
# appboost_users                                                    NaN
# vpn_users                                                         NaN
# shredder_users                                                    NaN
# quickclean_users                                                  NaN
# wbStatus                                                          NaN
# waStatus                                                          NaN
# non_av_users                                                      NaN
# no_of_features                                                    NaN
# 0_month_renewal                                                     0
# 1_month_renewal                                                     0

# %% [markdown]
# ## Basic Stats

# %%
journey9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11955165 entries, 0 to 11955164
# Data columns (total 40 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   expiry_principal_subscription_id             int64
#  1   subscription_expiry_month                    object
#  2   subscription_registration_month              object
#  3   subscription_expirying_in_month              float64
#  4   Journey                                      float64
#  5   months_since_registration                    int64
#  6   subscription_expiry_transition_type          object
#  7   subscription_expiry_length                   object
#  8   subscription_expiry_affiliate_id             int64
#  9   subscription_expiry_affiliate_name           object
#  10  subscription_expiry_channel                  object
#  11  subscription_expiry_transaction_source       object
#  12  subscription_expiry_package_id               int64
#  13  subscription_expiry_package_name             object
#  14  pkg_license_cnt                              object
#  15  subscription_expiry_user_click_source_group  object
#  16  subscription_expiring_country                object
#  17  subscription_expiring_geo                    object
#  18  Opt_in_out_status                            object
#  19  opt_out_date                                 object
#  20  opt_in_date                                  object
#  21  Lost_type                                    object
#  22  ar_on_rundate                                int64
#  23  renewal_Package_group                        object
#  24  All_device_count                             float64
#  25  PC_device_count                              float64
#  26  Mobile_device_count                          float64
#  27  cui_actions                                  float64
#  28  av_users                                     float64
#  29  app_launch_users                             float64
#  30  appboost_users                               float64
#  31  vpn_users                                    float64
#  32  shredder_users                               float64
#  33  quickclean_users                             float64
#  34  wbStatus                                     float64
#  35  waStatus                                     float64
#  36  non_av_users                                 float64
#  37  no_of_features                               float64
#  38  0_month_renewal                              int64
#  39  1_month_renewal                              int64
# dtypes: float64(16), int64(7), object(17)
# memory usage: 3.7+ GB

# %%
train = journey9[journey9["subscription_expiry_month"] == "2020-10-31"].sample(100000)
test = journey9[journey9["subscription_expiry_month"] == "2020-11-30"].sample(100000)

# %%
train.shape, test.shape
# Out:
# ((100000, 40), (100000, 40))

# %% [markdown]
# ### Value Counts

# %%
for col in train:
    vc = train[col].value_counts(normalize = True)
    l = len(vc)
    print(f"\n{'*'* 20}\n{col}. {l} unique values\n{'*' *20}")
    if l > 10:
        print(f"Showing top 10 items\n{'-'* 20}")
        print(vc.iloc[:10])
    else:
        print(vc)
# Out:
# ********************
# expiry_principal_subscription_id. 98919 unique values
# ********************
# Showing top 10 items
# --------------------
# 1640717545    0.00230
# 1264371254    0.00016
# 1303667786    0.00008
# 1252881270    0.00007
# 1640061315    0.00007
# 1494114129    0.00007
# 1175732690    0.00006
# 519211282     0.00006
# 1476770956    0.00006
# 1491666010    0.00006
# Name: expiry_principal_subscription_id, dtype: float64
#
# ********************
# subscription_expiry_month. 1 unique values
# ********************
# 2020-10-31    1.0
# Name: subscription_expiry_month, dtype: float64
#
# ********************
# subscription_registration_month. 125 unique values
# ********************
# Showing top 10 items
# --------------------
# 2019-10-31    0.35346
# 2018-10-31    0.15333
# 2017-10-31    0.08412
# 2016-10-31    0.06786
# 2015-10-31    0.04633
# 2014-10-31    0.03012
# 2019-09-30    0.02798
# 2018-09-30    0.02761
# 2018-08-31    0.02670
# 2019-01-31    0.02655
# Name: subscription_registration_month, dtype: float64
#
# ********************
# subscription_expirying_in_month. 1 unique values
# ********************
# 3.0    1.0
# Name: subscription_expirying_in_month, dtype: float64
#
# ********************
# Journey. 1 unique values
# ********************
# 9.0    1.0
# Name: Journey, dtype: float64
#
# ********************
# months_since_registration. 125 unique values
# ********************
# Showing top 10 items
# --------------------
# 12    0.35346
# 24    0.15333
# 36    0.08412
# 48    0.06786
# 60    0.04633
# 72    0.03012
# 13    0.02798
# 25    0.02761
# 26    0.02670
# 21    0.02655
# Name: months_since_registration, dtype: float64
#
# ********************
# subscription_expiry_transition_type. 3 unique values
# ********************
# Renew    0.54480
# Paid     0.25149
# Trial    0.20371
# Name: subscription_expiry_transition_type, dtype: float64
#
# ********************
# subscription_expiry_length. 1 unique values
# ********************
# 1 Year(s)    1.0
# Name: subscription_expiry_length, dtype: float64
#
# ********************
# subscription_expiry_affiliate_id. 183 unique values
# ********************
# Showing top 10 items
# --------------------
# 714     0.13603
# 105     0.11374
# 1357    0.09644
# 0       0.08538
# 1067    0.07500
# 739     0.06219
# 850     0.03935
# 885     0.03839
# 384     0.03773
# 662     0.03459
# Name: subscription_expiry_affiliate_id, dtype: float64
#
# ********************
# subscription_expiry_affiliate_name. 183 unique values
# ********************
# Showing top 10 items
# --------------------
# Lenovo Consumer             0.13603
# Dell                        0.11374
# HP Consumer 30D             0.09644
# McAfee                      0.08538
# Hewlett Packard Consumer    0.07500
# Adobe                       0.06219
# Media Markt                 0.03935
# ASUS                        0.03839
# DIXONS                      0.03773
# Acer Global                 0.03459
# Name: subscription_expiry_affiliate_name, dtype: float64
#
# ********************
# subscription_expiry_channel. 3 unique values
# ********************
# Partner    0.63294
# Retail     0.19593
# Direct     0.17113
# Name: subscription_expiry_channel, dtype: float64
#
# ********************
# subscription_expiry_transaction_source. 2 unique values
# ********************
# Website    0.79629
# Channel    0.20371
# Name: subscription_expiry_transaction_source, dtype: float64
#
# ********************
# subscription_expiry_package_id. 19 unique values
# ********************
# Showing top 10 items
# --------------------
# 430    0.59202
# 521    0.13661
# 539    0.06081
# 537    0.06049
# 535    0.05542
# 541    0.04315
# 536    0.01658
# 540    0.01615
# 275    0.01394
# 548    0.00191
# Name: subscription_expiry_package_id, dtype: float64
#
# ********************
# subscription_expiry_package_name. 19 unique values
# ********************
# Showing top 10 items
# --------------------
# McAfee LiveSafe                         0.59202
# McAfee® Total Protection                0.13661
# McAfee® LiveSafe - 1 Device             0.06081
# McAfee® Total Protection - 1 Device     0.06049
# McAfee® Total Protection - 5 Devices    0.05542
# McAfee® LiveSafe - 5 Devices            0.04315
# McAfee® Total Protection - 3 Devices    0.01658
# McAfee® LiveSafe - 3 Devices            0.01615
# 3-User McAfee Total Protection          0.01394
# McAfee® Total Protection - 7 Device     0.00191
# Name: subscription_expiry_package_name, dtype: float64
#
# ********************
# pkg_license_cnt. 8 unique values
# ********************
# UNLIMITED DEVICE    0.729980
# 1 DEVICE            0.121916
# 5 DEVICE            0.098753
# 3 DEVICE            0.046756
# 7 DEVICE            0.001914
# 12 DEVICE           0.000431
# 15 DEVICE           0.000190
# 10 DEVICE           0.000060
# Name: pkg_license_cnt, dtype: float64
#
# ********************
# subscription_expiry_user_click_source_group. 113 unique values
# ********************
# Showing top 10 items
# --------------------
# Not Applicable                         0.799312
# NGM_PHASE2_BUY_RENEW_TRACKINGngmMMA    0.053998
# NGM Cloud Alerts - Milestone           0.016082
# NGM_PHASE2_BUY_RENEW_TRACKINGngmMRA    0.011270
# SMAIL                                  0.010917
# buywindows                             0.010907
# COREUINGM                              0.009181
# BUYCOREUISIDEPANEL                     0.007022
# renewCoreUISidePanel                   0.006911
# BUYCOREUIHEADER                        0.006841
# Name: subscription_expiry_user_click_source_group, dtype: float64
#
# ********************
# subscription_expiring_country. 21 unique values
# ********************
# Showing top 10 items
# --------------------
# US        0.44643
# GB        0.14212
# Others    0.06555
# DE        0.05504
# JP        0.05348
# CA        0.03347
# AU        0.03014
# IN        0.02802
# ES        0.02231
# BR        0.02186
# Name: subscription_expiring_country, dtype: float64
#
# ********************
# subscription_expiring_geo. 4 unique values
# ********************
# EMEA     0.649376
# APAC     0.152608
# JAPAN    0.103205
# LTAM     0.094811
# Name: subscription_expiring_geo, dtype: float64
#
# ********************
# Opt_in_out_status. 2 unique values
# ********************
# opt-out    0.862752
# opt-in     0.137248
# Name: Opt_in_out_status, dtype: float64
#
# ********************
# opt_out_date. 4185 unique values
# ********************
# Showing top 10 items
# --------------------
# 2020-04-01 08:03:18.217    0.048462
# 2020-01-08 01:52:17.13     0.003371
# 2019-11-05 18:28:53.157    0.001686
# 2019-12-09 20:16:47.313    0.001475
# 2019-11-15 16:38:04.83     0.001264
# 2020-02-23 02:40:33.347    0.001264
# 2019-11-05 12:42:46.307    0.001264
# 2020-04-23 08:30:35.87     0.001264
# 2019-11-25 19:48:38.203    0.001054
# 2020-03-17 21:40:02.793    0.001054
# Name: opt_out_date, dtype: float64
#
# ********************
# opt_in_date. 688 unique values
# ********************
# Showing top 10 items
# --------------------
# 2019-10-28 17:08:41.387    0.009272
# 2019-10-28 17:18:43.387    0.007947
# 2019-10-01 13:20:56.137    0.007947
# 2020-06-21 12:26:37.45     0.006623
# 2019-10-12 15:54:31.543    0.005298
# 2020-07-18 18:58:00.367    0.005298
# 2019-10-09 05:27:32.71     0.005298
# 2019-10-05 15:36:43.66     0.003974
# 2019-10-19 03:13:13.74     0.003974
# 2019-10-04 13:55:52.11     0.003974
# Name: opt_in_date, dtype: float64
#
# ********************
# Lost_type. 4 unique values
# ********************
# Not Applicable                0.68006
# Sched To Expire               0.28873
# opt-out                       0.02666
# Cancel/Refund Post Renewal    0.00455
# Name: Lost_type, dtype: float64
#
# ********************
# ar_on_rundate. 2 unique values
# ********************
# 1    0.68854
# 0    0.31146
# Name: ar_on_rundate, dtype: float64
#
# ********************
# renewal_Package_group. 2 unique values
# ********************
# MLS    0.71373
# MTP    0.28627
# Name: renewal_Package_group, dtype: float64
#
# ********************
# All_device_count. 30 unique values
# ********************
# Showing top 10 items
# --------------------
# 1.0    0.598218
# 0.0    0.205421
# 2.0    0.117856
# 3.0    0.042281
# 4.0    0.017528
# 5.0    0.008912
# 6.0    0.004000
# 7.0    0.002031
# 8.0    0.001354
# 9.0    0.000874
# Name: All_device_count, dtype: float64
#
# ********************
# PC_device_count. 29 unique values
# ********************
# Showing top 10 items
# --------------------
# 1.0    0.659760
# 0.0    0.229935
# 2.0    0.076381
# 3.0    0.021223
# 4.0    0.006953
# 5.0    0.002811
# 6.0    0.001067
# 8.0    0.000477
# 7.0    0.000439
# 9.0    0.000238
# Name: PC_device_count, dtype: float64
#
# ********************
# Mobile_device_count. 14 unique values
# ********************
# Showing top 10 items
# --------------------
# 1.0    0.655764
# 2.0    0.172458
# 0.0    0.070252
# 3.0    0.057562
# 4.0    0.023644
# 5.0    0.010198
# 6.0    0.004532
# 7.0    0.002342
# 8.0    0.001889
# 9.0    0.000755
# Name: Mobile_device_count, dtype: float64
#
# ********************
# cui_actions. 2 unique values
# ********************
# 0.0    0.637889
# 1.0    0.362111
# Name: cui_actions, dtype: float64
#
# ********************
# av_users. 2 unique values
# ********************
# 1.0    0.938894
# 0.0    0.061106
# Name: av_users, dtype: float64
#
# ********************
# app_launch_users. 2 unique values
# ********************
# 0.0    0.644068
# 1.0    0.355932
# Name: app_launch_users, dtype: float64
#
# ********************
# appboost_users. 2 unique values
# ********************
# 0.0    0.775487
# 1.0    0.224513
# Name: appboost_users, dtype: float64
#
# ********************
# vpn_users. 2 unique values
# ********************
# 0.0    0.98831
# 1.0    0.01169
# Name: vpn_users, dtype: float64
#
# ********************
# shredder_users. 2 unique values
# ********************
# 0.0    0.984244
# 1.0    0.015756
# Name: shredder_users, dtype: float64
#
# ********************
# quickclean_users. 2 unique values
# ********************
# 1.0    0.54777
# 0.0    0.45223
# Name: quickclean_users, dtype: float64
#
# ********************
# wbStatus. 2 unique values
# ********************
# 0.0    0.935442
# 1.0    0.064558
# Name: wbStatus, dtype: float64
#
# ********************
# waStatus. 2 unique values
# ********************
# 1.0    0.822179
# 0.0    0.177821
# Name: waStatus, dtype: float64
#
# ********************
# non_av_users. 7 unique values
# ********************
# 2.0    0.579181
# 1.0    0.239698
# 3.0    0.128008
# 0.0    0.028499
# 4.0    0.022233
# 5.0    0.002256
# 6.0    0.000125
# Name: non_av_users, dtype: float64
#
# ********************
# no_of_features. 9 unique values
# ********************
# 3.0    0.420869
# 4.0    0.229597
# 2.0    0.199043
# 5.0    0.095047
# 1.0    0.033738
# 6.0    0.019250
# 7.0    0.002156
# 0.0    0.000175
# 8.0    0.000125
# Name: no_of_features, dtype: float64
#
# ********************
# 0_month_renewal. 2 unique values
# ********************
# 1    0.61401
# 0    0.38599
# Name: 0_month_renewal, dtype: float64
#
# ********************
# 1_month_renewal. 2 unique values
# ********************
# 1    0.62145
# 0    0.37855
# Name: 1_month_renewal, dtype: float64

# %% [markdown]
# NOTES: Based on above stats^^
# - expiry_principal_subscription_id - ID Column
# - subscription_expiry_month - Month level Date Feature. Only 1 value. Retain for future purposeNot Needed now
# - subscription_registration_month (160 unique values)- Month level Date Feature
# - subscription_expirying_in_month - Complement of 'Journey' ==> remove
# - months_since_registration (will correlate with subscription_registration_month since subscription_expiry_month is the same)
# - subscription_expiry_length - Only 1 value. Retain for future purposes
# - subscription_expiry_affiliate_id. 244 unique values
# - subscription_expiry_affiliate_name - Remove. Redundant w/ aff id
# - subscription_expiry_package_name - Remove. Redundant w/ pkg id
# - opt_out_date - Remove.
# - opt_in_date - Remove
# ________________________
# - 0_month_renewal - target variable
# - 1_month_renewal - Ancillary target varibale. Remove for now

# %% [markdown]
# ## Preprocessing

# %%
ID_COLS = ["expiry_principal_subscription_id"]
TARGET_COL = "0_month_renewal"
REM_COLS = ["1_month_renewal",
            "opt_out_date",
            "opt_in_date",
            "subscription_expirying_in_month",
            "subscription_expiry_affiliate_name",
            "subscription_expiry_package_name",
            "subscription_expirying_in_month",
            ]

MONTH_DATE_FEATURES = [
    "subscription_registration_month", "subscription_expiry_month"]

NUM_COLS = [
    NUM_COL
    for NUM_COL in train.head().select_dtypes('number').columns
    if NUM_COL not in REM_COLS + ID_COLS + MONTH_DATE_FEATURES + [TARGET_COL]
]
OBJ_COLS = [
    OBJ_COL for OBJ_COL in train.head().select_dtypes('object').columns
    if OBJ_COL not in REM_COLS + ID_COLS + MONTH_DATE_FEATURES + [TARGET_COL]
]

# %%
print(f"\nNumerical Columns:\n{NUM_COLS}")
print(f"\nObject Columns:\n{OBJ_COLS}")
print(f"\n Date Columns:\n{MONTH_DATE_FEATURES}")
# Out:
# Numerical Columns:
# ['Journey', 'months_since_registration', 'subscription_expiry_affiliate_id', 'subscription_expiry_package_id', 'ar_on_rundate', 'All_device_count', 'PC_device_count', 'Mobile_device_count', 'cui_actions', 'av_users', 'app_launch_users', 'appboost_users', 'vpn_users', 'shredder_users', 'quickclean_users', 'wbStatus', 'waStatus', 'non_av_users', 'no_of_features']
#
# Object Columns:
# ['subscription_expiry_transition_type', 'subscription_expiry_length', 'subscription_expiry_channel', 'subscription_expiry_transaction_source', 'pkg_license_cnt', 'subscription_expiry_user_click_source_group', 'subscription_expiring_country', 'subscription_expiring_geo', 'Opt_in_out_status', 'Lost_type', 'renewal_Package_group']
#
#  Date Columns:
# ['subscription_registration_month', 'subscription_expiry_month']

# %%
X_train, y_train = train.drop(columns=TARGET_COL), train[TARGET_COL]
X_test, y_test = test.drop(columns=TARGET_COL), test[TARGET_COL]

# %% [markdown]
# ### Feature Pipelines

# %%
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.impute import SimpleImputer

# %%
num_processor = Pipeline([
    ('mean_imputer', DFImputer(strategy='constant', fill_value=0)),
])

obj_processor = Pipeline(
    [
        ('str_imputer', DFImputer(strategy="most_frequent", missing_values= None)),
        ('dummify', DFLabelEncoder())
    ]
)

date_processor = Pipeline(
    [
        ('date_convert', DateFormatter()),
        ('date_add_field', DateTransformer())
    ]
)

preprocess_pipeline = ColumnTransformer(
    [
        ('date_proc', date_processor, MONTH_DATE_FEATURES),
        ('num_proc', num_processor, NUM_COLS),
        ('obj_proc', obj_processor, OBJ_COLS)
    ],
    remainder='drop'
)
# Out:
# Hey there! Today I'm gonna impute. My strategy is gonna be constant and my fillvalue is 0
# Hey there! Today I'm gonna impute. My strategy is gonna be most_frequent and my fillvalue is nothing

# %%
obj_processor.fit_transform(train[OBJ_COLS].iloc[:1]).tail().T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e32b71388930> in <module>
# ----> 1 obj_processor.fit_transform(train[OBJ_COLS].iloc[:1]).tail().T
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit_transform(self, X, y, **fit_params)
#     365         """
#     366         fit_params_steps = self._check_fit_params(**fit_params)
# --> 367         Xt = self._fit(X, y, **fit_params_steps)
#     368
#     369         last_step = self._final_estimator
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     290                 cloned_transformer = clone(transformer)
#     291             # Fit or load from cache the current transformer
# --> 292             X, fitted_transformer = fit_transform_one_cached(
#     293                 cloned_transformer, X, y, None,
#     294                 message_clsname='Pipeline',
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738     with _print_elapsed_time(message_clsname, message):
#     739         if hasattr(transformer, 'fit_transform'):
# --> 740             res = transformer.fit_transform(X, y, **fit_params)
#     741         else:
#     742             res = transformer.fit(X, y, **fit_params).transform(X)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~\OneDrive - McAfee\Documents\Projects\Covid Cohort\Health Dashboard\utils.py in fit(self, X, y)
#      45
#      46     def fit(self, X, y=None):
# ---> 47         self.imp.fit(X)
#      48         print(f"Did someone just fit my imputer?")
#      49         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     275         self : SimpleImputer
#     276         """
# --> 277         X = self._validate_input(X, in_fit=True)
#     278         super()._fit_indicator(X)
#     279
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
#     249                 raise new_ve from None
#     250             else:
# --> 251                 raise ve
#     252
#     253         _check_inputs_dtype(X, self.missing_values)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
#     239
#     240         try:
# --> 241             X = self._validate_data(X, reset=in_fit,
#     242                                     accept_sparse='csc', dtype=dtype,
#     243                                     force_all_finite=force_all_finite,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643
#     644         if force_all_finite:
# --> 645             _assert_all_finite(array,
#     646                                allow_nan=force_all_finite == 'allow-nan')
#     647
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     103     elif X.dtype == np.dtype('object') and not allow_nan:
#     104         if _object_dtype_isnan(X).any():
# --> 105             raise ValueError("Input contains NaN")
#     106
#     107
#
# ValueError: Input contains NaN

# %% [markdown]
# # Models

# %% [markdown]
# ## Baseline Model

# %%
model_pipe = Pipeline(steps=[
    ('preprocess', preprocess_pipeline),
    ('model', RandomForestClassifier(n_jobs = -1))
]).fit(X_train, y_train);
